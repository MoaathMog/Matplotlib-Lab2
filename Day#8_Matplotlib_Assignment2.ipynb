# %%
import numpy as np

# %% [markdown]
# # Q1: Import matplotlib library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Q2: Create a one line chart using two arrays. The first array represents x and the second array represents y
# | x     |     y    |
# | ----- | -------- |
# | 1    | 1       |
# | 2    | 2       |
# | 3    | 3       |
# | 4    | 5       |
# | 5    | 8       |
# | 6    | 13      |
# | 7    | 20      |

# %%
arrayX = [1,2,3,4,5,6,7]
arrayY = [1,2,3,5,8,13,20]

plt.plot(arrayX,arrayY)

# %% [markdown]
# # Q3: Create a two lines chart using the same previous arrays.
# But this time:
# - Mark each point with a circle.
# - Use dashed lines.
# - Set the size of the marker (circle) to size 10.
# - Set the width of the line to 3.
# - Add legends. 'Normal' for array x and 'Fast' for array y.

# %%
plt.scatter(arrayX,arrayY,s=10,c='black')
plt.plot(arrayX,arrayY,linestyle='--',linewidth=3,c='g')
plt.legend(['Normal','Fast'])

# %% [markdown]
# # Q4: Display multiple linear charts in one row using the charts given below.
# - Give each chart a title
# - Add a super title 'my data visulaization assignment'.

# %%
#super title = my data visulaization assignment

#title = First Chart
x_plot1 = np.array([1, 2, 3, 4, 5, 6, 7])
y_plot1 = np.array([1, 1, 2, 3, 5, 8, 13])

#title = Second Chart
x_plot2 = np.array([0, 1, 2, 3, 4, 5, 6])
y_plot2 = np.array([2, 4, 6, 8, 10, 12, 14])

#title = Third Chart
x_plot3 = np.array([0, 1, 3, 4])
y_plot3 = np.array([4, 6, 3, 4])

# %%
plt.figure()
plt.suptitle('my data visulaization assignment',fontsize = 20)

plt.subplot(331, title='First Chart')
plt.plot(x_plot1,y_plot1)

plt.subplot(332, title='Second Chart')
plt.plot(x_plot2,y_plot2)

plt.subplot(333, title='Third Chart')
plt.plot(x_plot3,y_plot3)

# %% [markdown]
# # Q5: Define an array that has a values of your top three TV series and define another array to hold the rating of the three TV series out of 10. Create a bar chart using the two arrays
# - Set a new color for the bars.
# - Change the width of the bars to width 0.5.

# %%
fav_movies = np.array(['Her','Fight Club','Se7en','Pulp fiction','Blade Runner'])
movie_rating = np.array([8.0,9.6,9.5,8.8,8.6])
colors=['#C9123e','#71342C','orange','yellow','purple']
plt.bar(fav_movies, movie_rating,color=colors,width=0.5,edgecolor='black')
plt.ylabel("Rating")
# Out:
# Text(0, 0.5, 'Rating')

# %% [markdown]
# # Q6: Create a scatter plot  using two arrays. The first array represents carAge and the second array represents carSpeed, set a specific color for each dot by using an array of different colors and add labels for the plot
# | carAge | carSpeed |
# | ----- | -------- |
# | 5    | 99       |
# | 7    | 86       |
# | 8    |87      |
# | 7    | 88       |
# | 2    | 111       |
# | 17    | 86       |
# | 2    | 103      |
# | 9    | 87       |
# | 4    | 94       |
# | 11    | 78      |

# %% [markdown]
# - Set a new color for each dot by using an array of different colors.
# - Change the size of the dots to size 350.
# - Add labels for x-axis and y-axis.
# - Adjust the transparency of the dots with the alpha argument. let the alpha value be 0.4

# %%
carAge = np.array([5,6,7,7,2,17,2,99,4,11])
carSpeed = np.array([99,86,87,88,111,86,103,87,94,78])
colors = np.random.rand(10)
plt.scatter(carAge,carSpeed,c=colors,s=350,alpha=0.4)
plt.xlabel('Car age')
plt.ylabel('Car speed')
# Out:
# Text(0, 0.5, 'Car speed')

# %% [markdown]
# # Q7: Create a pie chart using two arrays. The first array represents python_libraries and the second array represents your skills out of 10 at each library
# | python_libraries |
# | ------------ |
# | NumPy        |
# | Pandas       |
# | Matplotlib   |
# | Seaborn      |
# | Plotly       |
# | Scikit-learn |

# %% [markdown]
# - Set a new color for each wedge by using an array of different colors.
# - Pull your favorite library wedge 0.3 from the center of the pie.
# - Add a shadow to the pie chart

# %%
python_libraries = ['NumPy','Pandas','Matplotlib','Seaborn','Plotly','Scikit-learn']
my_skills = [7,9,8,5,6,4]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#C9123e','yellow']
#not accurate
plt.pie(my_skills,labels=python_libraries,colors=colors,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21a23835ae0>,
#   <matplotlib.patches.Wedge at 0x21a23836110>,
#   <matplotlib.patches.Wedge at 0x21a238367a0>,
#   <matplotlib.patches.Wedge at 0x21a23836e30>,
#   <matplotlib.patches.Wedge at 0x21a238374c0>,
#   <matplotlib.patches.Wedge at 0x21a23837b50>],
#  [Text(0.929709086335512, 0.5879124210162494, 'NumPy'),
#   Text(-0.3060392420142564, 1.0565699136107083, 'Pandas'),
#   Text(-1.096433035229012, -0.0885132716517501, 'Matplotlib'),
#   Text(-0.4715617447767338, -0.9937955125996106, 'Seaborn'),
#   Text(0.4715619308684271, -0.9937954242979995, 'Plotly'),
#   Text(1.0433901335986118, -0.34833465103126227, 'Scikit-learn')],
#  [Text(0.5071140470920974, 0.32067950237249965, '17.9%'),
#   Text(-0.16693049564413986, 0.5763108619694772, '23.1%'),
#   Text(-0.5980543828521883, -0.04827996635550005, '20.5%'),
#   Text(-0.25721549715094566, -0.5420702795997876, '12.8%'),
#   Text(0.2572155986555057, -0.5420702314352723, '15.4%'),
#   Text(0.5691218910537882, -0.19000071874432484, '10.3%')])

# %% [markdown]
# # Q8: Create a histogram with 250 values and 15 bars

# %%
np.random.seed(10**7)
x = np.random.randn(250)
x = x*10
plt.hist(x, bins=15, density = 1, color ='blue',alpha = 0.7,edgecolor='black')
# Out:
# (array([0.0057297 , 0.00458376, 0.01489723, 0.01031347, 0.0309404 ,
#         0.02291881, 0.03323228, 0.04583762, 0.04469168, 0.02291881,
#         0.01833505, 0.01718911, 0.0057297 , 0.0057297 , 0.00343782]),
#  array([-26.21879789, -22.72821547, -19.23763305, -15.74705063,
#         -12.25646821,  -8.76588579,  -5.27530337,  -1.78472095,
#           1.70586147,   5.19644389,   8.68702631,  12.17760873,
#          15.66819115,  19.15877357,  22.649356  ,  26.13993842]),
#  <BarContainer object of 15 artists>)
